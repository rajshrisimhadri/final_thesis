# %%
import torch
print(torch.__version__)
# Out:
# 2.5.1

# %%
import os
import scipy.io
import numpy as np
from scipy.signal.windows import hann
from scipy.fft import fft
import torch
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
# STFT Parameters
fs = 12000
fi = 100
Nseg1 = int(fs / fi)
Nseg2 = Nseg1 // 2
Nseg3 = Nseg1 // 4
Nfft = 256
overlap_ratio = 0.9
target_shape = (128, 64, 3)  #  Add this line

# %%
# Fault class label mapping
def get_class_label(fault_type, diameter, folder):
    if folder.lower() == 'normal':
        return 'c0'
    if fault_type == 'B':
        return {'007': 'c1', '014': 'c2', '021': 'c3', '028': 'c10'}.get(diameter, 'Unknown')
    elif fault_type == 'IR':
        return {'007': 'c4', '014': 'c5', '021': 'c6', '028': 'c11'}.get(diameter, 'Unknown')
    elif fault_type == 'OR':
        return {'007': 'c7', '014': 'c8', '021': 'c9', '028': 'c12'}.get(diameter, 'Unknown')
    return 'Unknown'

# %%
# STFT computation function
def compute_stft(x, Nseg, Nfft, overlap_ratio=0.9):
    Nover = int(Nseg * overlap_ratio)
    Nstep = Nseg - Nover
    Nframe = (len(x) - Nseg) // Nstep
    X = np.zeros((Nframe, Nfft))
    window = hann(Nseg)
    for n in range(Nframe):
        start = n * Nstep
        end = start + Nseg
        segment = x[start:end] * window
        spectrum = np.abs(fft(segment, Nfft))
        X[n, :] = spectrum
    return X.T

# %%
# Function: Pad or truncate tensor to fixed shape
def fix_tensor_shape(tensor, target_shape=(128, 64, 3)):
    h, w, c = tensor.shape
    H, W, C = target_shape

    # Truncate if needed
    tensor = tensor[:H, :W, :C]

    # Pad if smaller
    padded = np.zeros(target_shape)
    padded[:tensor.shape[0], :tensor.shape[1], :tensor.shape[2]] = tensor
    return padded

# %%
# Directory with .mat files
base_dir = '/home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data'
processed_data = []

print(" Starting delta STFT preprocessing...\n")

# Traverse all .mat files
for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith('.mat'):
            mat_path = os.path.join(root, file)
            print(f" Processing file: {mat_path}")

            try:
                mat_data = scipy.io.loadmat(mat_path)
                signal_keys = [k for k in mat_data.keys() if '_time' in k and not k.startswith('__')]
                print(f"     Found keys: {signal_keys}")

                rel_path = os.path.relpath(mat_path, base_dir)
                path_parts = rel_path.split(os.sep)

                if len(path_parts) >= 3:
                    fault_type = path_parts[0]
                    diameter = path_parts[1]
                else:
                    fault_type = diameter = 'Unknown'

                folder = path_parts[0]
                class_label = get_class_label(fault_type, diameter, folder)
                print(f"     Fault: {fault_type}, Diameter: {diameter}, Label: {class_label}")

                for key in signal_keys:
                    signal = mat_data[key].squeeze()
                    print(f"      Signal key: {key} | Length: {len(signal)}")

                    # Compute STFTs at multiple resolutions
                    X1 = compute_stft(signal, Nseg1, Nfft)
                    X2 = compute_stft(signal, Nseg2, Nfft)
                    X3 = compute_stft(signal, Nseg3, Nfft)

                    # Align time axis
                    min_frames = min(X1.shape[1], X2.shape[1], X3.shape[1])
                    X1, X2, X3 = X1[:, :min_frames], X2[:, :min_frames], X3[:, :min_frames]

                    # Compute delta STFTs
                    D1 = X1 - X2
                    D2 = X1 - X3
                    D3 = X2 - X3

                    raw_tensor = np.stack([D1[:128], D2[:128], D3[:128]], axis=-1)
                    delta_stft_tensor = fix_tensor_shape(raw_tensor, target_shape=target_shape)

                    # Store sample
                    processed_data.append({
                        "tensor": delta_stft_tensor,
                        "label": class_label,
                        "file_path": mat_path,
                        "key": key
                    })

            except Exception as e:
                print(f" Error processing {mat_path}: {e}")

print(f"\n Finished preprocessing. Total delta STFT samples prepared: {len(processed_data)}")
# Out:
#  Starting delta STFT preprocessing...
#
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/B/021/290_0.mat
#      Found keys: ['X290_DE_time', 'X290_FE_time', 'X290_BA_time']
#      Fault: B, Diameter: 021, Label: c3
#       Signal key: X290_DE_time | Length: 121351
#       Signal key: X290_FE_time | Length: 121351
#       Signal key: X290_BA_time | Length: 121351
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/B/021/292_2.mat
#      Found keys: ['X292_DE_time', 'X292_FE_time', 'X292_BA_time']
#      Fault: B, Diameter: 021, Label: c3
#       Signal key: X292_DE_time | Length: 121535
#       Signal key: X292_FE_time | Length: 121535
#       Signal key: X292_BA_time | Length: 121535
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/B/021/291_1.mat
#      Found keys: ['X291_DE_time', 'X291_FE_time', 'X291_BA_time']
#      Fault: B, Diameter: 021, Label: c3
#       Signal key: X291_DE_time | Length: 121351
#       Signal key: X291_FE_time | Length: 121351
#       Signal key: X291_BA_time | Length: 121351
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/B/021/293_3.mat
#      Found keys: ['X293_DE_time', 'X293_FE_time', 'X293_BA_time']
#      Fault: B, Diameter: 021, Label: c3
#       Signal key: X293_DE_time | Length: 120801
#       Signal key: X293_FE_time | Length: 120801
#       Signal key: X293_BA_time | Length: 120801
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/B/014/288_2.mat
#      Found keys: ['X288_DE_time', 'X288_FE_time', 'X288_BA_time']
#      Fault: B, Diameter: 014, Label: c2
#       Signal key: X288_DE_time | Length: 122269
#       Signal key: X288_FE_time | Length: 122269
#       Signal key: X288_BA_time | Length: 122269
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/B/014/286_0.mat
#      Found keys: ['X286_DE_time', 'X286_FE_time', 'X286_BA_time']
#      Fault: B, Diameter: 014, Label: c2
#       Signal key: X286_DE_time | Length: 122086
#       Signal key: X286_FE_time | Length: 122086
#       Signal key: X286_BA_time | Length: 122086
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/B/014/287_1.mat
#      Found keys: ['X287_DE_time', 'X287_FE_time', 'X287_BA_time']
#      Fault: B, Diameter: 014, Label: c2
#       Signal key: X287_DE_time | Length: 121719
#       Signal key: X287_FE_time | Length: 121719
#       Signal key: X287_BA_time | Length: 121719
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/B/014/289_3.mat
#      Found keys: ['X289_DE_time', 'X289_FE_time', 'X289_BA_time']
#      Fault: B, Diameter: 014, Label: c2
#       Signal key: X289_DE_time | Length: 121168
#       Signal key: X289_FE_time | Length: 121168
#       Signal key: X289_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/B/007/284_2.mat
#      Found keys: ['X284_DE_time', 'X284_FE_time', 'X284_BA_time']
#      Fault: B, Diameter: 007, Label: c1
#       Signal key: X284_DE_time | Length: 121719
#       Signal key: X284_FE_time | Length: 121719
#       Signal key: X284_BA_time | Length: 121719
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/B/007/283_1.mat
#      Found keys: ['X283_DE_time', 'X283_FE_time', 'X283_BA_time']
#      Fault: B, Diameter: 007, Label: c1
#       Signal key: X283_DE_time | Length: 120801
#       Signal key: X283_FE_time | Length: 120801
#       Signal key: X283_BA_time | Length: 120801
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/B/007/282_0.mat
#      Found keys: ['X282_DE_time', 'X282_FE_time', 'X282_BA_time']
#      Fault: B, Diameter: 007, Label: c1
#       Signal key: X282_DE_time | Length: 121168
#       Signal key: X282_FE_time | Length: 121168
#       Signal key: X282_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/B/007/285_3.mat
#      Found keys: ['X285_DE_time', 'X285_FE_time', 'X285_BA_time']
#      Fault: B, Diameter: 007, Label: c1
#       Signal key: X285_DE_time | Length: 121168
#       Signal key: X285_FE_time | Length: 121168
#       Signal key: X285_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/IR/021/273_3.mat
#      Found keys: ['X273_DE_time', 'X273_FE_time', 'X273_BA_time']
#      Fault: IR, Diameter: 021, Label: c6
#       Signal key: X273_DE_time | Length: 121168
#       Signal key: X273_FE_time | Length: 121168
#       Signal key: X273_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/IR/021/271_1.mat
#      Found keys: ['X271_DE_time', 'X271_FE_time', 'X271_BA_time']
#      Fault: IR, Diameter: 021, Label: c6
#       Signal key: X271_DE_time | Length: 121168
#       Signal key: X271_FE_time | Length: 121168
#       Signal key: X271_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/IR/021/272_2.mat
#      Found keys: ['X272_DE_time', 'X272_FE_time', 'X272_BA_time']
#      Fault: IR, Diameter: 021, Label: c6
#       Signal key: X272_DE_time | Length: 120984
#       Signal key: X272_FE_time | Length: 120984
#       Signal key: X272_BA_time | Length: 120984
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/IR/021/270_0.mat
#      Found keys: ['X270_DE_time', 'X270_FE_time', 'X270_BA_time']
#      Fault: IR, Diameter: 021, Label: c6
#       Signal key: X270_DE_time | Length: 121168
#       Signal key: X270_FE_time | Length: 121168
#       Signal key: X270_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/IR/014/275_1.mat
#      Found keys: ['X275_DE_time', 'X275_FE_time', 'X275_BA_time']
#      Fault: IR, Diameter: 014, Label: c5
#       Signal key: X275_DE_time | Length: 121351
#       Signal key: X275_FE_time | Length: 121351
#       Signal key: X275_BA_time | Length: 121351
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/IR/014/277_3.mat
#      Found keys: ['X277_DE_time', 'X277_FE_time', 'X277_BA_time']
#      Fault: IR, Diameter: 014, Label: c5
#       Signal key: X277_DE_time | Length: 121168
#       Signal key: X277_FE_time | Length: 121168
#       Signal key: X277_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/IR/014/274_0.mat
#      Found keys: ['X274_DE_time', 'X274_FE_time', 'X274_BA_time']
#      Fault: IR, Diameter: 014, Label: c5
#       Signal key: X274_DE_time | Length: 121351
#       Signal key: X274_FE_time | Length: 121351
#       Signal key: X274_BA_time | Length: 121351
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/IR/014/276_2.mat
#      Found keys: ['X276_DE_time', 'X276_FE_time', 'X276_BA_time']
#      Fault: IR, Diameter: 014, Label: c5
#       Signal key: X276_DE_time | Length: 121351
#       Signal key: X276_FE_time | Length: 121351
#       Signal key: X276_BA_time | Length: 121351
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/IR/007/281_3.mat
#      Found keys: ['X281_DE_time', 'X281_FE_time', 'X281_BA_time']
#      Fault: IR, Diameter: 007, Label: c4
#       Signal key: X281_DE_time | Length: 121535
#       Signal key: X281_FE_time | Length: 121535
#       Signal key: X281_BA_time | Length: 121535
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/IR/007/278_0.mat
#      Found keys: ['X278_DE_time', 'X278_FE_time', 'X278_BA_time']
#      Fault: IR, Diameter: 007, Label: c4
#       Signal key: X278_DE_time | Length: 121535
#       Signal key: X278_FE_time | Length: 121535
#       Signal key: X278_BA_time | Length: 121535
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/IR/007/279_1.mat
#      Found keys: ['X279_DE_time', 'X279_FE_time', 'X279_BA_time']
#      Fault: IR, Diameter: 007, Label: c4
#       Signal key: X279_DE_time | Length: 121351
#       Signal key: X279_FE_time | Length: 121351
#       Signal key: X279_BA_time | Length: 121351
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/IR/007/280_2.mat
#      Found keys: ['X280_DE_time', 'X280_FE_time', 'X280_BA_time']
#      Fault: IR, Diameter: 007, Label: c4
#       Signal key: X280_DE_time | Length: 121351
#       Signal key: X280_FE_time | Length: 121351
#       Signal key: X280_BA_time | Length: 121351
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/021/@6/315_0.mat
#      Found keys: ['X315_DE_time', 'X315_FE_time', 'X315_BA_time']
#      Fault: OR, Diameter: 021, Label: c9
#       Signal key: X315_DE_time | Length: 120617
#       Signal key: X315_FE_time | Length: 120617
#       Signal key: X315_BA_time | Length: 120617
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/021/@3/317_2.mat
#      Found keys: ['X317_DE_time', 'X317_FE_time', 'X317_BA_time']
#      Fault: OR, Diameter: 021, Label: c9
#       Signal key: X317_DE_time | Length: 120617
#       Signal key: X317_FE_time | Length: 120617
#       Signal key: X317_BA_time | Length: 120617
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/021/@3/316_1.mat
#      Found keys: ['X316_DE_time', 'X316_FE_time', 'X316_BA_time']
#      Fault: OR, Diameter: 021, Label: c9
#       Signal key: X316_DE_time | Length: 120617
#       Signal key: X316_FE_time | Length: 120617
#       Signal key: X316_BA_time | Length: 120617
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/021/@3/318_3.mat
#      Found keys: ['X318_DE_time', 'X318_FE_time', 'X318_BA_time']
#      Fault: OR, Diameter: 021, Label: c9
#       Signal key: X318_DE_time | Length: 121351
#       Signal key: X318_FE_time | Length: 121351
#       Signal key: X318_BA_time | Length: 121351
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/014/@6/313_0.mat
#      Found keys: ['X313_DE_time', 'X313_FE_time', 'X313_BA_time']
#      Fault: OR, Diameter: 014, Label: c8
#       Signal key: X313_DE_time | Length: 120984
#       Signal key: X313_FE_time | Length: 120984
#       Signal key: X313_BA_time | Length: 120984
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/014/@3/312_3.mat
#      Found keys: ['X312_DE_time', 'X312_FE_time', 'X312_BA_time']
#      Fault: OR, Diameter: 014, Label: c8
#       Signal key: X312_DE_time | Length: 120984
#       Signal key: X312_FE_time | Length: 120984
#       Signal key: X312_BA_time | Length: 120984
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/014/@3/311_2.mat
#      Found keys: ['X311_DE_time', 'X311_FE_time', 'X311_BA_time']
#      Fault: OR, Diameter: 014, Label: c8
#       Signal key: X311_DE_time | Length: 120984
#       Signal key: X311_FE_time | Length: 120984
#       Signal key: X311_BA_time | Length: 120984
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/014/@3/309_1.mat
#      Found keys: ['X309_DE_time', 'X309_FE_time', 'X309_BA_time']
#      Fault: OR, Diameter: 014, Label: c8
#       Signal key: X309_DE_time | Length: 121168
#       Signal key: X309_FE_time | Length: 121168
#       Signal key: X309_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/014/@3/310_0.mat
#      Found keys: ['X310_DE_time', 'X310_FE_time', 'X310_BA_time']
#      Fault: OR, Diameter: 014, Label: c8
#       Signal key: X310_DE_time | Length: 121535
#       Signal key: X310_FE_time | Length: 121535
#       Signal key: X310_BA_time | Length: 121535
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/007/@12/305_1.mat
#      Found keys: ['X305_DE_time', 'X305_FE_time', 'X305_BA_time']
#      Fault: OR, Diameter: 007, Label: c7
#       Signal key: X305_DE_time | Length: 120984
#       Signal key: X305_FE_time | Length: 120984
#       Signal key: X305_BA_time | Length: 120984
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/007/@12/306_2.mat
#      Found keys: ['X306_DE_time', 'X306_FE_time', 'X306_BA_time']
#      Fault: OR, Diameter: 007, Label: c7
#       Signal key: X306_DE_time | Length: 121719
#       Signal key: X306_FE_time | Length: 121719
#       Signal key: X306_BA_time | Length: 121719
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/007/@12/302_0.mat
#      Found keys: ['X302_DE_time', 'X302_FE_time', 'X302_BA_time']
#      Fault: OR, Diameter: 007, Label: c7
#       Signal key: X302_DE_time | Length: 121168
#       Signal key: X302_FE_time | Length: 121168
#       Signal key: X302_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/007/@12/307_3.mat
#      Found keys: ['X307_DE_time', 'X307_FE_time', 'X307_BA_time']
#      Fault: OR, Diameter: 007, Label: c7
#       Signal key: X307_DE_time | Length: 121168
#       Signal key: X307_FE_time | Length: 121168
#       Signal key: X307_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/007/@6/297_3.mat
#      Found keys: ['X297_DE_time', 'X297_FE_time', 'X297_BA_time']
#      Fault: OR, Diameter: 007, Label: c7
#       Signal key: X297_DE_time | Length: 121902
#       Signal key: X297_FE_time | Length: 121902
#       Signal key: X297_BA_time | Length: 121902
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/007/@6/294_0.mat
#      Found keys: ['X294_DE_time', 'X294_FE_time', 'X294_BA_time']
#      Fault: OR, Diameter: 007, Label: c7
#       Signal key: X294_DE_time | Length: 121168
#       Signal key: X294_FE_time | Length: 121168
#       Signal key: X294_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/007/@6/296_2.mat
#      Found keys: ['X296_DE_time', 'X296_FE_time', 'X296_BA_time']
#      Fault: OR, Diameter: 007, Label: c7
#       Signal key: X296_DE_time | Length: 121168
#       Signal key: X296_FE_time | Length: 121168
#       Signal key: X296_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/007/@6/295_1.mat
#      Found keys: ['X295_DE_time', 'X295_FE_time', 'X295_BA_time']
#      Fault: OR, Diameter: 007, Label: c7
#       Signal key: X295_DE_time | Length: 121535
#       Signal key: X295_FE_time | Length: 121535
#       Signal key: X295_BA_time | Length: 121535
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/007/@3/299_1.mat
#      Found keys: ['X299_DE_time', 'X299_FE_time', 'X299_BA_time']
#      Fault: OR, Diameter: 007, Label: c7
#       Signal key: X299_DE_time | Length: 121168
#       Signal key: X299_FE_time | Length: 121168
#       Signal key: X299_BA_time | Length: 121168
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/007/@3/300_2.mat
#      Found keys: ['X300_DE_time', 'X300_FE_time', 'X300_BA_time']
#      Fault: OR, Diameter: 007, Label: c7
#       Signal key: X300_DE_time | Length: 121902
#       Signal key: X300_FE_time | Length: 121902
#       Signal key: X300_BA_time | Length: 121902
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/007/@3/301_3.mat
#      Found keys: ['X301_DE_time', 'X301_FE_time', 'X301_BA_time']
#      Fault: OR, Diameter: 007, Label: c7
#       Signal key: X301_DE_time | Length: 121719
#       Signal key: X301_FE_time | Length: 121719
#       Signal key: X301_BA_time | Length: 121719
#  Processing file: /home/rsimhadr/Downloads/CWRU-dataset/12k_Fan_End_Bearing_Fault_Data/OR/007/@3/298_0.mat
#      Found keys: ['X298_DE_time', 'X298_FE_time', 'X298_BA_time']
#      Fault: OR, Diameter: 007, Label: c7
#       Signal key: X298_DE_time | Length: 120984
#       Signal key: X298_FE_time | Length: 120984
#       Signal key: X298_BA_time | Length: 120984
#
#  Finished preprocessing. Total delta STFT samples prepared: 135

# %%
# STEP 1: Extract tensors and labels
X = np.array([item["tensor"] for item in processed_data])  # shape: (N, 128, 64, 3)
y = np.array([item["label"] for item in processed_data])   # shape: (N,)

print(f" Raw dataset shape → X: {X.shape}, y: {y.shape}")

# STEP 2: Encode class labels (e.g., 'c0' → 0, 'c1' → 1, ...)
le = LabelEncoder()
y_encoded = le.fit_transform(y)
print(f" Encoded labels: {np.unique(y_encoded)} | Total classes: {len(le.classes_)}")

# STEP 3: Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, stratify=y_encoded, random_state=42
)

# STEP 4: Show final dataset sizes
print(f" Train data shape: X_train = {X_train.shape}, y_train = {y_train.shape}")
print(f" Test  data shape: X_test  = {X_test.shape}, y_test  = {y_test.shape}")
# Out:
#  Raw dataset shape → X: (135, 128, 64, 3), y: (135,)
#  Encoded labels: [0 1 2 3 4 5 6 7 8] | Total classes: 9
#  Train data shape: X_train = (108, 128, 64, 3), y_train = (108,)
#  Test  data shape: X_test  = (27, 128, 64, 3), y_test  = (27,)

# %%
labels = [item["label"] for item in processed_data]
unique_classes = sorted(set(labels))

print(f" Unique class labels: {unique_classes}")
print(f" Total number of unique fault classes: {len(unique_classes)}")
# Out:
#  Unique class labels: ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']
#  Total number of unique fault classes: 9

# %%
# Convert numpy arrays to torch tensors and reorder to (N, C, H, W)
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).permute(0, 3, 1, 2)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32).permute(0, 3, 1, 2)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# Create datasets
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print(" DataLoaders are ready.")
# Out:
#  DataLoaders are ready.

# %%
# Check one batch from train_loader
train_batch = next(iter(train_loader))
X_batch, y_batch = train_batch

print(" Train Loader Batch Shape:")
print("X_batch shape:", X_batch.shape)  # (batch_size, 3, 128, 64)
print("y_batch shape:", y_batch.shape)  # (batch_size,)

# Check one batch from test_loader
test_batch = next(iter(test_loader))
X_test_batch, y_test_batch = test_batch

print("\n Test Loader Batch Shape:")
print("X_batch shape:", X_test_batch.shape)
print("y_batch shape:", y_test_batch.shape)
# Out:
#  Train Loader Batch Shape:
# X_batch shape: torch.Size([32, 3, 128, 64])
# y_batch shape: torch.Size([32])
#
#  Test Loader Batch Shape:
# X_batch shape: torch.Size([27, 3, 128, 64])
# y_batch shape: torch.Size([27])

# %%
print(f"Total samples: {len(processed_data)}")
print(processed_data[0].keys())
# Out:
# Total samples: 135
# dict_keys(['tensor', 'label', 'file_path', 'key'])

# %%
print(processed_data[0]['tensor'].shape)
# Out:
# (128, 10102, 3)

# %%
labels = [d['label'] for d in processed_data]
unique_labels = sorted(set(labels))
print(f"Number of unique labels: {len(unique_labels)}")
print("Labels:", unique_labels)
# Out:
# Number of unique labels: 9
# Labels: ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']
